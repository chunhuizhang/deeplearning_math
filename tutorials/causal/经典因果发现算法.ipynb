# %% [markdown]
# ###  Peter-Clark (PC) 算法

# %% [markdown]
# > 从一个全连接的无向图 到 真实的因果图：仅凭观测数据（无干预），从变量集合里发现因果结构，输出一个代表马尔可夫等价类的图——CPDAG（部分有向无环图）。
#
# - https://zhuanlan.zhihu.com/p/612839966
#     - https://causal-learn.readthedocs.io/en/latest/search_methods_index/Constraint-based%20causal%20discovery%20methods/PC.html
