# %% [markdown]
# >  k-dimensional tree（k维树）
#
# 想象一下，在KDE的计算中，对于一个新的点 x_query，我们需要计算它和所有数据点 x_i 的关系。如果你的数据集有100万个点，那么每查询一个点的密度，就要做100万次计算。这太慢了！
#
# 但我们很快会发现，对于 x_query，那些离它十万八千里的点 x_i 对其密度贡献几乎为零。我们真正关心的，只是 x_query 附近的那些点。
#
# 核心问题：如何快速地只找出 x_query 附近的点，而不用检查所有100万个点？
#
# 答案：预先对数据点进行智能的组织和划分。KD树就是这种智能的组织方式之一。
