# %% [markdown]
# - references
#     - https://medium.com/@okanyenigun/step-by-step-guide-to-bayesian-optimization-a-python-based-approach-3558985c6818

# %%
from IPython.display import Image

# %% [markdown]
# ## basics

# %% [markdown]
# > Bayesian optimization is a technique used for the global (optimum) optimization of black-box functions.

# %%
Image('../../imgs/Comparison-between-a-grid-search-and-b-random-search-for-hyper-parameter-tuning-The.png', 
     width=600)

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(42)

def black_box_function(x):
    y = np.sin(x) + np.cos(2*x)
    return y

# %%
# range of x values
x_range = np.linspace(-2*np.pi, 2*np.pi, 100)

# output for each x value
black_box_output = black_box_function(x_range)

# %%
plt.plot(x_range, black_box_output)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Black Box Function Output')
plt.show()
