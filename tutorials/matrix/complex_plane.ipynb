# %% [markdown]
# ## basics

# %% [markdown]
# $$
# \begin{split}
# e^{i\pi}+1&=0\\
# e^{i\pi}+1&=\left(\cos\pi + i\sin\pi\right) + 1 = -1 + 1=0
# \end{split}
# $$
#
# - $x=a+ib$
#     - $e^{x}=e^{a+ib}=e^ae^{ib}=e^a\left(\cos b+i\sin b\right)$

# %% [markdown]
# ## unit circle

# %% [markdown]
# - $e^{i\theta}$ 就是一个单位圆

# %%
import numpy as np
import matplotlib.pyplot as plt

thetas = np.linspace(-2*np.pi, 2*np.pi, 500)

xs = np.real(np.exp(1j*thetas))
ys = np.imag(np.exp(1j*thetas))

plt.plot(xs, ys)
plt.axis('equal')
# Out:
# (-1.0999791907454364,
#  1.099999009083116,
#  -1.0999945499436368,
#  1.0999945499436368)
